# %%
#import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import Data
df = pd.read_csv('kc_house_data.csv')
df.head(5).T
# Out:
#                              0                1                2  \
# id                  7129300520       6414100192       5631500400
# date           20141013T000000  20141209T000000  20150225T000000
# price                 221900.0         538000.0         180000.0
# bedrooms                     3                3                2
# bathrooms                  1.0             2.25              1.0
# sqft_living               1180             2570              770
# sqft_lot                  5650             7242            10000
# floors                     1.0              2.0              1.0
# waterfront                   0                0                0
# view                         0                0                0
# condition                    3                3                3
# grade                        7                7                6
# sqft_above                1180             2170              770
# ...

# %%
#get some information about our Data-Set
df.info()
df.describe().transpose()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
# drop some unnecessary columns
df = df.drop(['date','id','zipcode'],axis=1)

# %%
X = df.drop('price',axis =1).values
y = df['price'].values
#splitting Train and Test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (14480, 17)
# (14480,)
# (7133, 17)
# (7133,)

# %%
#standardization scaler - fit&transform on train, fit only on test
from sklearn.preprocessing import StandardScaler
s_scaler = StandardScaler()
X_train = s_scaler.fit_transform(X_train.astype(np.double))
X_test = s_scaler.transform(X_test.astype(np.double))

# %%
# Creating a Neural Network Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import optimizers

# %%
def create_model(opt):
  model = Sequential()
  model.add(Dense(64,activation='relu'))
  model.add(Dense(32,activation='relu'))
  model.add(Dense(16,activation='relu'))
  model.add(Dense(1))

  model.compile(optimizer=opt,loss=tf.keras.losses.MeanSquaredError())

  return model

sgd = optimizers.SGD(learning_rate=0.0001)
mini_batchgd = optimizers.SGD(learning_rate=0.01)
adagrad = optimizers.Adagrad(learning_rate=0.01, epsilon=1e-7)
rmsprop = optimizers.RMSprop(learning_rate=0.01, epsilon=1e-7, rho=0.9)
adam = optimizers.Adam(learning_rate=0.01, epsilon=1e-7, beta_1=0.9, beta_2=0.999)
adadelta = optimizers.Adadelta(learning_rate=0.01, rho=0.9, epsilon=1e-7)

# %%
model = create_model(mini_batchgd)

history = model.fit(x=X_train,y=y_train, validation_split=0.1,
          batch_size=1,epochs=10)
# Out:
# Epoch 1/10
# 13032/13032 [==============================] - 25s 2ms/step - loss: nan - val_loss: nan
# Epoch 2/10
# 13032/13032 [==============================] - 23s 2ms/step - loss: nan - val_loss: nan
# Epoch 3/10
# 13032/13032 [==============================] - 26s 2ms/step - loss: nan - val_loss: nan
# Epoch 4/10
# 13032/13032 [==============================] - 26s 2ms/step - loss: nan - val_loss: nan
# Epoch 5/10
# 13032/13032 [==============================] - 25s 2ms/step - loss: nan - val_loss: nan
# Epoch 6/10
# 13032/13032 [==============================] - 24s 2ms/step - loss: nan - val_loss: nan
# Epoch 7/10
# 13032/13032 [==============================] - 25s 2ms/step - loss: nan - val_loss: nan
# Epoch 8/10
# 13032/13032 [==============================] - 25s 2ms/step - loss: nan - val_loss: nan
# Epoch 9/10
# 13032/13032 [==============================] - 25s 2ms/step - loss: nan - val_loss: nan
# Epoch 10/10
# ...

# %%
model.summary()

# %%
#loss_df = pd.DataFrame(model.history.history)
#loss_df.plot(figsize=(12,8))

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
#compare actual output values with predicted values
y_pred = model.predict(X_test)

# evaluate the performance of the algorithm (MAE - MSE - RMSE)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))

# %%
model = create_model(mini_batch)

history = model.fit(x=X_train,y=y_train, validation_split=0.1,
          batch_size=1,epochs=20)
