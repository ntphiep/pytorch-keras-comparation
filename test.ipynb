# %%
import torch

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
torch.randn(2, 5)
# Out:
# tensor([[ 0.0135,  0.5008, -0.1938, -0.4613, -0.0301],
#         [-0.4085, -1.1142, -0.0998, -0.3691,  0.7507]])

# %%
y = torch.exp(x)
y
# Out:
# tensor(7.3891, grad_fn=<ExpBackward0>)

# %%
y.backward()

# %%
y.grad_fn

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 3)

# %%
torch.rand(1, 32, 32)
# Out:
# tensor([[[0.0925, 0.4719, 0.7365,  ..., 0.5650, 0.9209, 0.3395],
#          [0.3998, 0.5442, 0.5887,  ..., 0.1511, 0.1726, 0.2395],
#          [0.3185, 0.1347, 0.8503,  ..., 0.1423, 0.3048, 0.7361],
#          ...,
#          [0.3180, 0.9750, 0.6566,  ..., 0.5053, 0.7958, 0.4633],
#          [0.6192, 0.0230, 0.6452,  ..., 0.5676, 0.5274, 0.7703],
#          [0.7183, 0.3117, 0.5764,  ..., 0.0059, 0.1750, 0.3312]]])

# %%
x = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
x_gpu = x.to(device='cuda')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 x = torch.tensor([[4.0, 1.0], [5.0, 3.0], [2.0, 1.0]])
# ----> 2 x_gpu = x.to(device='cuda')
#
# File c:\Users\DangTinh\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:293, in _lazy_init()
#     288     raise RuntimeError(
#     289         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     290         "multiprocessing, you must use the 'spawn' start method"
#     291     )
#     292 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 293     raise AssertionError("Torch not compiled with CUDA enabled")
#     294 if _cudart is None:
#     295     raise AssertionError(
#     296         "libcudart functions unavailable. It looks like you have a broken build?"
#     297     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
import torch
import torch.nn as nn

# Định nghĩa một mô hình đơn giản với một lớp tuyến tính
class SimpleModel(nn.Module):
    def __init__(self):
        super(SimpleModel, self).__init__()
        self.fc = nn.Linear(10, 5)

    def forward(self, x):
        # Quá trình chuyển tiếp (forward pass)
        x = self.fc(x)
        return x

# Tạo một đối tượng mô hình
model = SimpleModel()

# Tạo một tensor đầu vào giả lập
input_tensor = torch.randn(3, 10)  # 3 là số lượng mẫu, 10 là số lượng đặc trưng

# Thực hiện chuyển tiếp qua mô hình bằng cách gọi phương thức forward
output_tensor = model(input_tensor)

# In kích thước đầu ra để kiểm tra
print("Kích thước đầu ra:", output_tensor.size())
# Out:
# Kích thước đầu ra: torch.Size([3, 5])

# %%
input_tensor
# Out:
# tensor([[-1.2605e+00, -4.2244e-01, -8.8499e-01,  1.4985e+00, -2.4129e-01,
#          -9.8236e-01, -5.5878e-01, -2.7612e-03, -1.2113e+00,  7.9665e-01],
#         [-3.2430e-02, -1.2005e+00,  1.1677e+00,  2.2846e-01,  3.0081e-05,
#           3.3818e-01, -4.2839e-01, -4.9637e-01, -5.3857e-02,  1.3659e+00],
#         [-5.2399e-01,  1.4169e+00, -1.7038e+00,  1.4918e-01,  1.2238e-01,
#          -1.4997e+00,  1.0736e+00,  1.3584e+00, -8.8371e-02,  4.9375e-01]])

# %%
output_tensor
# Out:
# tensor([[ 0.5745, -0.8586,  0.7353, -0.3585, -0.1750],
#         [-0.4385, -0.7322,  0.1423,  0.4455,  0.0323],
#         [ 0.8182, -0.2683, -0.2699, -0.8702, -0.1103]],
#        grad_fn=<AddmmBackward0>)

# %%
import numpy as np 
W = np.array([0.3, 1.2])
b = 0.7

# %%
import torch
from torch import nn
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import numpy as np

# %%
np.random.normal(loc=0, scale=1, size=1)
# Out:
# array([-2.87828679])

# %%
def get_y_noise(X):
    noise = np.random.normal(loc=0, scale=1, size=1)
    y = np.matmul(X, W) + b
    result = y + noise
    return result

def get_y(X):
    y = np.matmul(X, W) + b
    return y

# %%
X = np.random.random(size=(1000, 2)) * 10
X
# Out:
# array([[3.49679266, 2.44414451],
#        [4.63310041, 0.38583536],
#        [5.21568043, 9.41807027],
#        ...,
#        [2.79776232, 3.46332366],
#        [7.21077125, 8.2879159 ],
#        [1.8432403 , 5.15623465]])

# %%
X = X.reshape(-1, 2)
X
# Out:
# array([[3.49679266, 2.44414451],
#        [4.63310041, 0.38583536],
#        [5.21568043, 9.41807027],
#        ...,
#        [2.79776232, 3.46332366],
#        [7.21077125, 8.2879159 ],
#        [1.8432403 , 5.15623465]])

# %%
y = np.apply_along_axis(get_y, axis=1, arr=X)
y = y.reshape(-1, 1)

# %%
def create_figure(X, y):
    fig = plt.figure(figsize=(8, 8))

    # add axes
    ax = fig.add_subplot(111,projection='3d')
    
    # plot the plane    
    ax.scatter(X[:, 0], X[:, 1], y, marker="o")     
    ax.set_xlabel('X feature 1')
    ax.set_ylabel('X feature 2')
    ax.set_zlabel('Y')

    plt.show()
    

create_figure(X, y)

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super(LinearRegression, self).__init__()
        self.linear_fn = nn.Linear(2, 1)
    
    def forward(self, X):
        logits = self.linear_fn(X)
        return logits

# %%
model = LinearRegression()
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, weight_decay=0.01)
loss_fn = torch.nn.MSELoss()

# %%
print(model)
# Out:
# LinearRegression(
#   (linear_fn): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
def print_param(model):
    for name, param in model.named_parameters():
        print(f"name: {name}, param: {param}, gradients: {param.grad}") 
        
print_param(model)
# Out:
# name: linear_fn.weight, param: Parameter containing:
# tensor([[-0.0125,  0.4296]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([-0.3587], requires_grad=True), gradients: None

# %%
X = torch.tensor(X, dtype=torch.float)
y = torch.tensor(y, dtype=torch.float)

epochs = 400
for epoch in range(1, epochs + 1):
    optimizer.zero_grad()

    predicted_y = model(X)
    # loss = loss_fn(predicted_y, obs_y)
    loss = loss_fn(predicted_y, y)
    # print(f"Predicted {predicted_y}")
    # print(f"Truth_value {y}")
    if epoch % 50 == 0:
        print(f"Epoch:{epoch}, MSE: {loss}")   
        print_param(model)            

    # Don't want buffer to carry on
    loss.backward()    
    optimizer.step()
# Out:
# Epoch:50, MSE: 0.10052743554115295
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3708, 1.2695]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([-0.1243], requires_grad=True), gradients: None
# Epoch:100, MSE: 0.07486428320407867
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3611, 1.2600]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([-0.0113], requires_grad=True), gradients: None
# Epoch:150, MSE: 0.05581814795732498
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3528, 1.2518]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.0858], requires_grad=True), gradients: None
# Epoch:200, MSE: 0.04167385771870613
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3456, 1.2447]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.1693], requires_grad=True), gradients: None
# Epoch:250, MSE: 0.031162235885858536
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3395, 1.2386]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.2411], requires_grad=True), gradients: None
# Epoch:300, MSE: 0.02334381826221943
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3342, 1.2334]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.3028], requires_grad=True), gradients: None
# Epoch:350, MSE: 0.017523016780614853
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3297, 1.2288]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.3559], requires_grad=True), gradients: None
# Epoch:400, MSE: 0.013184680603444576
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3258, 1.2250]], requires_grad=True), gradients: None
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.4015], requires_grad=True), gradients: None

# %%
print_param(model)
# Out:
# name: linear_fn.weight, param: Parameter containing:
# tensor([[0.3257, 1.2249]], requires_grad=True), gradients: tensor([[ 0.0040, -0.0051]])
# name: linear_fn.bias, param: Parameter containing:
# tensor([0.4023], requires_grad=True), gradients: tensor([-0.0884])

# %%
def create_compare_figure(X, y, y_pred):
    fig = plt.figure(figsize=(8, 8))

    # add axes
    ax = fig.add_subplot(111,projection='3d')
    
    # plot the plane    
    ax.scatter(X[:, 0], X[:, 1], y, marker="o", alpha=0.5, label="truth_y") 
    ax.scatter(X[:, 0], X[:, 1], y_pred, marker="o", color="red", alpha=0.5, label="predicted_y")     
    ax.set_xlabel('X feature 1')
    ax.set_ylabel('X feature 2')
    ax.set_zlabel('Y')
    ax.legend()

    plt.show()

# Dự đoán và chuyển từ tensor thành numpy    
y_pred = model(X).detach().numpy()
create_compare_figure(X, y, y_pred)

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = torch.exp(x)
y
# Out:
# tensor(7.3891, grad_fn=<ExpBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(7.3891)

# %%
a = torch.tensor([2., 3.])
a
# Out:
# tensor([2., 3.])

# %%
x = torch.ones(2, 2, requires_grad = True)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.]], requires_grad=True)
